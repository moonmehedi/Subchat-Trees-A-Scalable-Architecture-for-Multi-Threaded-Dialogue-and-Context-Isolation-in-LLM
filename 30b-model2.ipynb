# %% [markdown]
# # 🚀 Kaggle Buffer Test Runner - All-in-One
#
# This notebook loads vLLM, registers it with the backend, and runs buffer tests.
# **Run all cells in order - no separate notebook needed!**
#
# ## What this does:
# 1. ✅ Installs vLLM dependencies
# 2. ✅ Loads Qwen 14B AWQ model on Kaggle GPUs
# 3. ✅ Clones repo and configures git
# 4. ✅ Registers vLLM with backend (for responses, summarization, AND judging)
# 5. ✅ Runs buffer tests (sizes: 5, 10, 20, 40)
# 6. ✅ Auto-pushes results to GitHub after each buffer
#
# ## Important:
# - This is a **single notebook** - no need for separate notebooks
# - vLLM model stays in memory for all operations
# - No server needed - tests use direct Python imports

# %%
# Cell 1: Install vLLM dependencies + ROUGE/BLEU for recall probes
print("="*60)
print("📦 INSTALLING vLLM DEPENDENCIES + RECALL PROBE LIBS")
print("="*60)

import importlib.metadata
from pathlib import Path
import shutil
import subprocess
import sys

# Preserve existing Kaggle NumPy. Do NOT downgrade NumPy in live Kaggle kernel.
try:
    installed_numpy = importlib.metadata.version("numpy")
except importlib.metadata.PackageNotFoundError:
    installed_numpy = None

# IMPORTANT:
# Your Kaggle account has Pillow core 11.3.0 but metadata became 12.2.0.
# So force Pillow back to 11.3.0.
PINNED_PILLOW = "11.3.0"

constraint_args = []
constraints_path = Path("/kaggle/working/subchat_constraints.txt")

constraint_lines = []
if installed_numpy:
    constraint_lines.append(f"numpy=={installed_numpy}")
    print(f"🔒 Preserving existing NumPy {installed_numpy}")

constraint_lines.append(f"pillow=={PINNED_PILLOW}")
constraints_path.write_text("\n".join(constraint_lines) + "\n")
constraint_args = ["-c", str(constraints_path)]

print(f"🔒 Preserving/fixing Pillow {PINNED_PILLOW}")


def pip_install(*packages, check=True):
    if shutil.which("uv"):
        cmd = ["uv", "pip", "install", "-q", "--system", "--upgrade"]
    else:
        cmd = [sys.executable, "-m", "pip", "install", "-q", "--upgrade"]

    cmd.extend(packages)
    cmd.extend(constraint_args)

    print("$", " ".join(cmd))
    return subprocess.run(cmd, check=check)


def pip_install_no_deps(*packages, check=True):
    if shutil.which("uv"):
        cmd = ["uv", "pip", "install", "-q", "--system", "--reinstall", "--no-deps"]
    else:
        cmd = [sys.executable, "-m", "pip", "install", "-q", "--force-reinstall", "--no-deps"]

    cmd.extend(packages)

    print("$", " ".join(cmd))
    return subprocess.run(cmd, check=check)


def pip_uninstall(*packages):
    if shutil.which("uv"):
        cmd = ["uv", "pip", "uninstall", "-q", "--system", *packages]
    else:
        cmd = [sys.executable, "-m", "pip", "uninstall", "-y", "-q", *packages]

    print("$", " ".join(cmd))
    return subprocess.run(cmd, check=False)


# Remove packages that often trigger fragile vision/PIL paths.
pip_uninstall("tensorflow", "torchvision")

# Install main packages.
pip_install("vllm", "triton==3.2.0", "logits-processor-zoo")
pip_install("rouge-score>=0.1.2", "nltk>=3.8.0")

# CRITICAL FIX:
# Force Pillow 11.3.0 LAST, without changing dependencies.
pip_install_no_deps("pillow==11.3.0")

# Verify NumPy ABI.
import numpy as np
import numpy.random as _np_random
_np_random.RandomState(0)

# Verify Pillow binary.
from PIL import Image
print(f"✅ Pillow import OK ({Image.__version__})")

# Download NLTK tokenizer data.
import nltk
nltk.download("punkt", quiet=True)
nltk.download("punkt_tab", quiet=True)

print(f"✅ Dependencies installed; NumPy ABI OK ({np.__version__})")
print("="*60)

# %%
# Cell 2: Import libraries
import os
import shutil
import subprocess
import sys

# Text-only runner. Keep vision disabled as much as possible.
os.environ["TRANSFORMERS_NO_TORCHVISION"] = "1"
os.environ["TRANSFORMERS_NO_VISION"] = "1"

# Remove already-loaded fragile modules, if any.
for name in list(sys.modules):
    if (
        name == "torchvision"
        or name.startswith("torchvision.")
        or name == "PIL"
        or name.startswith("PIL.")
    ):
        del sys.modules[name]

# Block torchvision discovery.
try:
    import importlib.util

    original_find_spec = importlib.util.find_spec

    def _no_vision_find_spec(name, package=None):
        if name == "torchvision" or name.startswith("torchvision"):
            return None
        return original_find_spec(name, package)

    importlib.util.find_spec = _no_vision_find_spec

except Exception as exc:
    print(f"⚠️ Could not install torchvision import guard: {exc}")

# Tell transformers vision is unavailable.
try:
    from transformers.utils import import_utils as _tf_import_utils
    _tf_import_utils._torchvision_available = False
    _tf_import_utils._vision_available = False
except Exception as exc:
    print(f"⚠️ Could not pre-disable transformers vision imports: {exc}")

import numpy as np

# Fail early with a clear message if NumPy is broken.
try:
    import numpy.random as _np_random
    _np_random.RandomState(0)
except ValueError as exc:
    raise RuntimeError(
        "NumPy binary ABI mismatch detected. Restart the Kaggle session, "
        "then rerun this notebook from Cell 1."
    ) from exc

# Verify Pillow before importing vLLM.
try:
    from PIL import Image
    print(f"✅ Pillow version: {Image.__version__}")
except Exception as exc:
    raise RuntimeError(
        "Pillow is still broken. In Cell 1, make sure this line runs LAST:\n"
        "pip_install_no_deps('pillow==11.3.0')"
    ) from exc

import torch
import vllm
from logits_processor_zoo.vllm import MultipleChoiceLogitsProcessor

print("="*60)
print("📚 LIBRARIES IMPORTED")
print("="*60)
print(f"✅ NumPy version: {np.__version__}")
print(f"✅ Pillow version: {Image.__version__}")
print(f"✅ PyTorch version: {torch.__version__}")
print(f"✅ vLLM version: {vllm.__version__}")
print(f"✅ CUDA available: {torch.cuda.is_available()}")
print(f"🎮 GPUs available: {torch.cuda.device_count()}")

if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        print(f"   GPU {i}: {torch.cuda.get_device_name(i)}")

print("="*60)

# %%
# Cell 3: Load Kaggle secrets and set environment
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

# Load all secrets
os.environ["GITHUB_TOKEN"] = user_secrets.get_secret("GITHUB_TOKEN")
os.environ["GROQ_API_KEY"] = user_secrets.get_secret("GROQ_API_KEY")
os.environ["HuggingFACEHUB_access_token"] = user_secrets.get_secret("HuggingFACEHUB_access_token")
os.environ["LANGCHAIN_API_KEY"] = user_secrets.get_secret("LANGCHAIN_API_KEY")

# Set vLLM configuration
os.environ["LLM_BACKEND"] = "vllm"
model_path = "/kaggle/input/models/qwen-lm/qwen2.5/transformers/1.5b-instruct-awq/1"
os.environ["VLLM_MODEL_PATH"] = model_path
os.environ["VLLM_USE_V1"] = "0"

print("="*60)
print("🔐 SECRETS AND CONFIGURATION LOADED")
print("="*60)
print(f"✅ GITHUB_TOKEN: {os.environ['GITHUB_TOKEN'][:4]}...{os.environ['GITHUB_TOKEN'][-4:]}")
print(f"✅ LLM_BACKEND: vllm")
print(f"✅ VLLM_MODEL_PATH: {model_path}")
print("="*60)

# %%
# Cell 4: Load vLLM model on Kaggle GPUs (takes 2-3 minutes)
print("="*60)
print("🚀 LOADING vLLM MODEL")
print("="*60)
print(f"📂 Model: {model_path}")
print(f"🎮 GPUs: {torch.cuda.device_count()}")
print("⏳ This takes 2-3 minutes...")
print("="*60)

# Keep transformers vision disabled before touching tokenizer utilities.
os.environ["TRANSFORMERS_NO_TORCHVISION"] = "1"
os.environ["TRANSFORMERS_NO_VISION"] = "1"
for name in list(sys.modules):
    if name == "torchvision" or name.startswith("torchvision.") or name == "PIL" or name.startswith("PIL."):
        del sys.modules[name]
try:
    from transformers.utils import import_utils as _tf_import_utils
    _tf_import_utils._torchvision_available = False
    _tf_import_utils._vision_available = False
except Exception as exc:
    print(f"⚠️  Could not keep transformers vision disabled: {exc}")

# Compatibility fix for vLLM 0.8.x + some Transformers/Qwen tokenizer combos.
# This vLLM version only supports tokenizer_mode: auto, slow, mistral, custom.
# It may still ask slow Qwen tokenizers for all_special_tokens_extended, so add
# that property before vLLM initializes its tokenizer cache.
from transformers.tokenization_utils_base import PreTrainedTokenizerBase


def _all_special_tokens_extended(self):
    return getattr(self, "all_special_tokens", [])

PreTrainedTokenizerBase.all_special_tokens_extended = property(
    _all_special_tokens_extended
)
print("✅ Tokenizer compatibility shim installed")

llm = vllm.LLM(
    model_path,
    tokenizer=model_path,
    tokenizer_mode="auto",
    quantization='awq',
    tensor_parallel_size=torch.cuda.device_count(),
    gpu_memory_utilization=0.91,
    trust_remote_code=True,
    dtype="half",
    enforce_eager=True,
    max_model_len=5000,
    disable_log_stats=True,
    enable_prefix_caching=True
)
tokenizer = llm.get_tokenizer()

print("\n" + "="*60)
print("✅ vLLM MODEL LOADED SUCCESSFULLY!")
print("="*60)
print(f"   Memory per GPU: ~{torch.cuda.get_device_properties(0).total_memory / 1024**3 * 0.91:.1f}GB used")
print("="*60)

# %%
# Cell 5: Clone repository and configure git
REPO_URL = "https://github.com/moonmehedi/Subchat-Trees-A-Scalable-Architecture-for-Multi-Threaded-Dialogue-and-Context-Isolation-in-LLM.git"
REPO_DIR = "Subchat-Trees"
BRANCH = "kaggle-run"

print("="*60)
print("📥 CLONING REPOSITORY")
print("="*60)

# Remove existing directory if present
if os.path.exists(REPO_DIR):
    print(f"⚠️  Removing existing {REPO_DIR} directory...")
    shutil.rmtree(REPO_DIR)

# Clone with LFS skip to save bandwidth
clone_env = os.environ.copy()
clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"

result = subprocess.run(
    ["git", "clone", "-b", BRANCH, "--single-branch", REPO_URL, REPO_DIR],
    capture_output=True,
    text=True,
    env=clone_env
)

if result.returncode == 0:
    print(f"✅ Cloned {BRANCH} branch!")
    
    # Pull LFS files for scenarios
    os.chdir(REPO_DIR)
    subprocess.run(
        ["git", "lfs", "pull", "--include=backend/dataset/scenarios/*.json"],
        capture_output=True,
        text=True
    )
    print("✅ Pulled scenario files from Git LFS")
    
    # Configure git identity
    subprocess.run(["git", "config", "user.name", "moonmehedi"], check=True)
    subprocess.run(["git", "config", "user.email", "the.mehedi.hasan.moon@gmail.com"], check=True)
    print("✅ Git identity configured")
    
    os.chdir("..")
else:
    print(f"❌ Clone failed: {result.stderr}")

print("="*60)

# %%
# Cell 6: Register vLLM with backend
sys.path.insert(0, os.path.join(REPO_DIR, "backend"))

from src.services.vllm_client import VLLMClient

print("="*60)
print("🔗 REGISTERING vLLM WITH BACKEND")
print("="*60)

VLLMClient.set_model(llm)

print(f"✅ vLLM registered: {VLLMClient.is_available()}")
print("   ✅ Response generation will use vLLM")
print("   ✅ Summarization will use vLLM")
print("   ✅ Judge/Classification will use vLLM")
print("="*60)

# %%
# Cell 7: Install backend requirements
print("="*60)
print("📦 INSTALLING BACKEND REQUIREMENTS")
print("="*60)

import shutil
import subprocess
import sys
from pathlib import Path

# Preserve the NumPy version that already passed the ABI check in Cell 2.
import numpy as np
constraints_path = Path("/kaggle/working/subchat_constraints.txt")
constraints_path.write_text(
    f"numpy=={np.__version__}\n"
    "pillow==11.3.0\n"
)

if shutil.which("uv"):
    cmd = [
        "uv", "pip", "install", "-q", "--system",
        "-r", "/kaggle/working/Subchat-Trees/backend/requirements.txt",
        "-c", str(constraints_path),
    ]
else:
    cmd = [
        sys.executable, "-m", "pip", "install", "-q",
        "-r", "/kaggle/working/Subchat-Trees/backend/requirements.txt",
        "-c", str(constraints_path),
    ]
print("$", " ".join(cmd))
subprocess.run(cmd, check=True)

import numpy.random as _np_random
_np_random.RandomState(0)

print(f"✅ Backend requirements installed (NumPy {np.__version__} preserved)")
print("="*60)

# %%
# Cell 8: Quick test to verify vLLM integration works
from src.services.simple_llm import SimpleLLMClient
from src.models.tree import TreeNode

print("="*60)
print("🧪 QUICK INTEGRATION TEST")
print("="*60)

llm_client = SimpleLLMClient()
root = TreeNode(node_id="test", title="Test", buffer_size=5, llm_client=llm_client)
root.buffer.add_message("user", "Hello")

response = llm_client.generate_response(root, "What is 2+2?")
print(f"✅ Test response: {response[:100]}...")
print("✅ vLLM integration working!")
print("="*60)

# %%
# Cell 9: RUN BUFFER TESTS (SERVERLESS - no HTTP server needed!)
# Running on ENTIRE DATASET with robust error handling

print("="*60)
print("🚀 RUNNING SERVERLESS BUFFER TESTS - FULL DATASET")
print("="*60)
print("📊 Testing buffer sizes: 5, 10, 15, 20")
print("📄 Dataset: merged_realistic_interleaved.json (VBRI interleaved, 309 turns)")
print("📤 Results will auto-push to GitHub after each buffer")
print("⏳ This may take several hours")
print("✅ NO SERVER NEEDED - using direct Python imports!")
print("✅ Max output tokens: 300")
print("="*60)

os.chdir("/kaggle/working/Subchat-Trees/backend")

# Import and run the serverless test runner
import sys
import glob
from pathlib import Path
sys.path.insert(0, "/kaggle/working/Subchat-Trees/backend")
sys.path.insert(0, "/kaggle/working/Subchat-Trees/backend/dataset")

from dataset.kaggle_serverless_runner import ServerlessTestRunner

# Create runner
runner = ServerlessTestRunner()
runner.test_mode = "both"  # Run both baseline and system tests

# RUN ONLY THE MERGED INTERLEAVED DATASET
scenario_dir = Path("/kaggle/working/Subchat-Trees/backend/dataset/scenarios")
scenario_files = ["merged_realistic_interleaved.json"]

# Buffer sizes to test
buffer_sizes = [5,10,20]

print(f"\n📄 Discovered {len(scenario_files)} scenario files:")
for idx, file in enumerate(scenario_files, 1):
    print(f"   {idx}. {file}")
print(f"\n📦 Buffer sizes: {buffer_sizes}")
print(f"\n⏱️  Estimated time: ~{len(scenario_files) * len(buffer_sizes) * 15} minutes")
print("="*60)

# Validate scenarios before starting (quick check)
print("\n🔍 Validating scenario files...")
import json
valid_scenarios = []
for scenario_file in scenario_files:
    try:
        scenario_path = scenario_dir / scenario_file
        with open(scenario_path, 'r') as f:
            data = json.load(f)
            # Check for BOTH formats: "conversation" (old) and "conversations" (structured)
            if ("conversation" in data and isinstance(data["conversation"], list)) or \
               ("conversations" in data and isinstance(data["conversations"], list)):
                conv_key = "conversation" if "conversation" in data else "conversations"
                valid_scenarios.append(scenario_file)
                print(f"   ✅ {scenario_file} ({len(data[conv_key])} steps)")
            else:
                print(f"   ⚠️  {scenario_file} - skipping (invalid format)")
    except Exception as e:
        print(f"   ❌ {scenario_file} - skipping (error: {e})")

print(f"\n✅ {len(valid_scenarios)}/{len(scenario_files)} scenarios validated")
print("="*60)

if not valid_scenarios:
    print("❌ ERROR: No valid scenario files found!")
else:
    # Run the comparison with validated scenarios
    try:
        runner.run_buffer_comparison(
            valid_scenarios,
            buffer_sizes=buffer_sizes
        )
        print("\n" + "="*60)
        print("🎉 ALL TESTS COMPLETED SUCCESSFULLY!")
        print("="*60)
    except KeyboardInterrupt:
        print("\n⚠️  Tests interrupted by user")
    except Exception as e:
        print(f"\n❌ ERROR during test execution: {e}")
        import traceback
        traceback.print_exc()

# %%
# Cell 10: Completion and cleanup (optional)
print("="*60)
print("✅ BUFFER TESTS COMPLETE!")
print("="*60)
print("📤 All results have been pushed to GitHub")
print("📊 Check the kaggle_logs/ directory in your repo")
print("")
print("💡 You can now stop the kernel to save GPU quota")
print("   Uncomment the line below to auto-shutdown:")
print("="*60)

# Uncomment to force shutdown and save GPU quota:
# import os; os._exit(0)
